# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pur = pd.read_csv("Car_Purchasing_Data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-970a954f7350> in <module>()
# ----> 1 pur = pd.read_csv("Car_Purchasing_Data.csv")
#
# NameError: name 'pd' is not defined
